# %%
import qiskit
import qiskit_aer
import qiskit_finance
import qiskit_optimization
import matplotlib
import sys

print("--- Qiskit Environment Verification ---")
print(f"Python Version:         {sys.version.split()[0]}")
print(f"Qiskit Version:         {qiskit.__version__}")
print(f"Qiskit Aer Version:     {qiskit_aer.__version__}")
print(f"Qiskit Finance Version: {qiskit_finance.__version__}")
print(f"Qiskit Opt Version:     {qiskit_optimization.__version__}")
print(f"Matplotlib Version:     {matplotlib.__version__}")
print("---------------------------------------")
print("Environment successfully initialized!")
# Out:
# --- Qiskit Environment Verification ---
# Python Version:         3.14.4
# Qiskit Version:         2.4.1
# Qiskit Aer Version:     0.17.2
# Qiskit Finance Version: 0.4.1
# Qiskit Opt Version:     0.7.0
# Matplotlib Version:     3.10.9
# ---------------------------------------
# Environment successfully initialized!
